# %% [markdown]
# ### About Data
# The data is obtain from tableau public website. Its about the HollywoodsMostProfitableStories.

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Missing values with na_values parameter
# We can define a na_values parameter with the values we want to be recognized as NA/NaN. In this case empty strings " ", _, ?  - will be recognized as null values

# %%
# importing the data
stories_df = pd.read_csv("HollywoodsMostProfitableStories.csv", na_values=[" ", "?","-", "_"])

# %% [markdown]
# #### Checking in the size of our dataset
# 1.The number of total elements in the HollywoodsMostProfitableStories dataframe with both missing values included
#
# 2.The number of colums and rows in the dataframe

# %%
# Explore the size and number of rows and columns
print("THE SAMMARY OF OUR DATAFRAME")
print("Number of Elements:", stories_df.size)
# print("Number of Elements:", np.product(stories_df.shape)) # alternative for finding the size
print("Number of rows:", stories_df.shape[0])
print("Number of columns:", stories_df.shape[1])
stories_df.head()
# Out:
# THE SAMMARY OF OUR DATAFRAME
# Number of Elements: 592
# Number of rows: 74
# Number of columns: 8
#                    Film    Genre  Lead Studio  Audience_Score %  \
# 0            27 Dresses   Comedy          Fox              71.0
# 1  (500) Days of Summer   Comedy          Fox              81.0
# 2    A Dangerous Method    Drama  Independent              89.0
# 3         A Serious Man    Drama    Universal              64.0
# 4   Across the Universe  Romance  Independent              84.0
#
#    Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# 0       5.343622               40.0       160.308654  2008
# 1       8.096000               87.0        60.720000  2009
# 2       0.448645               79.0         8.972895  2011
# 3       4.382857               89.0        30.680000  2009
# 4       0.652603               54.0        29.367143  2007

# %% [markdown]
# ### Cleaning and preparing our data

# %% [markdown]
# ##### How many missing data points do we have in our dataset?

# %%
#number of missing data points per column
missing_values_count = stories_df.isnull().sum()
# look at the number of missing points in all columns
missing_values_count[0:]
# Out:
# Film                 0
# Genre                0
# Lead Studio          1
# Audience_Score %     1
# Profitability        3
# Rotten Tomatoes %    1
# Worldwide Gross      0
# Year                 0
# dtype: int64

# %% [markdown]
# ### Percentage of missing values
# That seems like a little! It might be helpful to see what percentage of the values in our dataset are missing to give us a better sense of the scale of this problem:

# %%
#total size and how many total missing values do we have?
total_size = stories_df.size
total_missing = missing_values_count.sum()

#percentage of the data missing
missing_percentage = (total_missing / total_size) * 100
print("The percentage of missing values: ",missing_percentage, "%")
# Out:
# The percentage of missing values:  1.0135135135135136 %

# %% [markdown]
# ## About missing values
# From above we could see that we have one missing value from the Lead studio.We could assume that the missing value is the independent studio or the the studio that came before in our data.since this could add noise to our data will drop the value and will only add a small significant change because it only one value.
# Now, with the Audience store%, Rotten Tomatoes% and Profitability its hard to guess the values it either it zero or they were never recorded.This bring us to conclusion to drop the values to avoid adding unesessary noice to data, also its only few values not recorded so will only lose small amount of data.

# %%
# Convert 'Year' to datetime
stories_df['Year'] = pd.to_datetime(stories_df['Year'], format='Y%')
#remove all the rows that contain a missing value
stories_df.dropna()
# Out:
#                                   Film    Genre            Lead Studio  \
# 0                           27 Dresses   Comedy                    Fox
# 1                 (500) Days of Summer   Comedy                    Fox
# 2                   A Dangerous Method    Drama            Independent
# 3                        A Serious Man    Drama              Universal
# 4                  Across the Universe  Romance            Independent
# ..                                 ...      ...                    ...
# 68                 Water For Elephants    Drama       20th Century Fox
# 69               What Happens in Vegas   Comedy                    Fox
# 71  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 72                     Youth in Revolt   Comedy  The Weinstein Company
# 73          Zack and Miri Make a Porno  Romance  The Weinstein Company
#
#     Audience_Score %  Profitability  Rotten Tomatoes %  Worldwide Gross  \
# 0               71.0       5.343622               40.0       160.308654
# 1               81.0       8.096000               87.0        60.720000
# 2               89.0       0.448645               79.0         8.972895
# 3               64.0       4.382857               89.0        30.680000
# 4               84.0       0.652603               54.0        29.367143
# ..               ...            ...                ...              ...
# 68              72.0       3.081421               60.0       117.094000
# 69              72.0       6.267647               28.0       219.367646
# 71              35.0       1.211818               43.0        26.660000
# 72              52.0       1.090000               68.0        19.620000
# 73              70.0       1.747542               64.0        41.941000
#
#          Year
# 0  2008-01-01
# 1  2009-01-01
# 2  2011-01-01
# 3  2009-01-01
# 4  2007-01-01
# ..        ...
# 68 2011-01-01
# 69 2008-01-01
# 71 2010-01-01
# 72 2010-01-01
# 73 2008-01-01
#
# [69 rows x 8 columns]

# %% [markdown]
# ## Explotary Analysis and Visualiazation

# %% [markdown]
# ###### Summary Statistics

# %%
# Compute summary statistics for numeric columns
summary_stats = stories_df.describe()
summary_stats
# Out:
#        Audience_Score %  Profitability  Rotten Tomatoes %  Worldwide Gross
# count         73.000000      71.000000          73.000000        74.000000
# mean          64.136986       4.741610          47.356164       136.351979
# std           13.647665       8.292017          26.242655       157.067561
# min           35.000000       0.005000           3.000000         0.025000
# 25%           52.000000       1.790680          27.000000        32.447500
# 50%           64.000000       2.642353          45.000000        73.198612
# 75%           76.000000       4.850958          65.000000       190.185250
# max           89.000000      66.934000          96.000000       709.820000

# %%
# Compute the range for 'Audience score %' and 'Rotten Tomatoes %'
range_audience_score = stories_df['Audience_Score %'].max() - stories_df['Audience_Score %'].min()
range_rotten_tomatoes = stories_df['Rotten Tomatoes %'].max() - stories_df['Rotten Tomatoes %'].min()

# %%
# printing the ranges 'Audience score %' and 'Rotten Tomatoes %'
print(f'range_audience_score : {range_audience_score}\nrange_rotten_tomatoes : {range_rotten_tomatoes}')
# Out:
# range_audience_score : 54.0
# range_rotten_tomatoes : 93.0

# %% [markdown]
# Finding the number of Genres and Lead Studios, together with there count using the value_count function. Also the number of movies produced each year in our data

# %%
#finding each genre count
genre_count = stories_df['Genre'].value_counts()
genre_count
# Out:
# Comedy       41
# Romance      15
# Drama        13
# Animation     3
# Action        1
# Fantasy       1
# Name: Genre, dtype: int64

# %%
#finding each studio count
studio_count = stories_df['Lead Studio'].value_counts()
studio_count
# Out:
# Independent              19
# Warner Bros.             12
# Universal                 7
# Disney                    7
# Fox                       6
# Summit                    5
# Sony                      4
# Paramount                 4
# The Weinstein Company     3
# Lionsgate                 2
# 20th Century Fox          2
# New Line                  1
# CBS                       1
# Name: Lead Studio, dtype: int64

# %%
#finding number of movies recorded/produced each year
year_count = stories_df['Year'].value_counts()
year_count
# Out:
# 2008    19
# 2010    19
# 2011    13
# 2009    12
# 2007    11
# Name: Year, dtype: int64

# %% [markdown]
# ###### Distributions & Relationships:

# %%
# getting the 'Audience score and Rotten Tomatoes columns'
audience_Tomatoes = stories_df.loc[:, ["Audience_Score %","Rotten Tomatoes %"]]

# %%
# Histogram for 'Audience score % and Rotten Tomatoes'
for column in audience_Tomatoes:
    plt.figure(figsize=(10, 6))
    sns.histplot(audience_Tomatoes[column], bins=20, kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(f'{column}')
    plt.ylabel('Frequency')
    plt.show()

# %%
# Scatter plot for 'Audience score %' vs. 'Rotten Tomatoes %'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=stories_df, x='Audience_Score %', y='Rotten Tomatoes %')
plt.title('Relationship between Audience Score % and Rotten Tomatoes %')
plt.xlabel('Audience Score %')
plt.ylabel('Rotten Tomatoes %')
plt.show()

# %%
# Scatter plot for 'Audience score %' vs.'Profitability'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=stories_df, x='Audience_Score %', y='Profitability')
plt.title('Relationship between Audience Score % and Profitability')
plt.xlabel('Profitability')
plt.ylabel('Audience_Score')
plt.show()

# %%
# Scatter plot for 'Profitability' vs. 'Worldwide Gross'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=stories_df, x='Profitability', y='Worldwide Gross')
plt.title('Relationship between Audience Score % and Profitability')
plt.xlabel('Profitability')
plt.ylabel('Audience_Score')
plt.show()

# %% [markdown]
# Analylization each Genre

# %%
#calculating mean of each genre
mean_by_genre = stories_df.groupby("Genre")[["Audience_Score %", "Rotten Tomatoes %", "Profitability", "Worldwide Gross"]].mean()
mean_by_genre = mean_by_genre.reset_index()

# %%
# bar charts for every variable with respect to the genre
mean_genre = mean_by_genre.iloc[:, 1:5]
for column in mean_genre:
    plt.figure(figsize=(6, 4))
    plt.bar(mean_by_genre["Genre"], mean_by_genre[column])
    plt.xlabel("Genre")
    plt.ylabel(column)
    plt.title(f"{column} by Genre")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Analylization each Lead studio

# %%
#calculating the mean of each Lead studio
mean_by_lead_studio = stories_df.groupby("Lead Studio")[["Audience_Score %", "Rotten Tomatoes %", "Profitability", "Worldwide Gross"]].mean()
mean_by_lead_studio = mean_by_lead_studio.reset_index()

# %%
# bar chart for each variable with respect to the lead studio
mean_studio = mean_by_lead_studio.iloc[:, 1:5]
for column in mean_studio:
    plt.figure(figsize=(6, 4))
    plt.bar(mean_by_lead_studio["Lead Studio"], mean_by_lead_studio[column])
    plt.xlabel("Lead Studio")
    plt.ylabel(column)
    plt.title(f"{column} by Lead Studio")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Analyzing each year

# %%
#grouping the years
grouped_by_year = stories_df.groupby("Year")[["Audience_Score %", "Rotten Tomatoes %", "Profitability", "Worldwide Gross"]].mean()
grouped_by_year = grouped_by_year.reset_index()

# %%
# bar chart for each variable with respect to the year
mean_year = grouped_by_year.iloc[:, 1:5]
for column in mean_year:
    plt.figure(figsize=(6, 4))
    plt.bar(grouped_by_year["Year"], grouped_by_year[column])
    plt.xlabel("Lead Studio")
    plt.ylabel(column)
    plt.title(f"{column} by Year")
    plt.xticks(rotation=45)
    plt.show()
